# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

data_raw = pd.read_csv('/home/marcel/catkin_ws/src/dynamic-model-car-simulator/data.csv')
data = pd.DataFrame(data=data_raw)
interest_a = 1990
interest_b = 2060
data[1990:2060] #19 30
#plt.plot(data['x'], data['t'])

#print('experiment end time: ' + repr(np.max(data['t'])) + 's')
# Out:
#             x         y      t  torque  steering_angle  long_vel   lat_vel  \
# 2052  10.8525  0.046759  20.52       0            0.53  0.979779  0.187317
# 2053  10.8622  0.048954  20.53       0            0.54  0.977533  0.191693
# 2054  10.8719  0.051204  20.54       0            0.55  0.975241  0.196056
# 2055  10.8816  0.053508  20.55       0            0.56  0.972903  0.200406
# 2056  10.8912  0.055867  20.56       0            0.57  0.970521  0.204740
# 2057  10.9008  0.058280  20.57       0            0.57  0.968094  0.209058
# 2058  10.9104  0.060744  20.58       0            0.57  0.965867  0.213004
# 2059  10.9200  0.063256  20.59       0            0.57  0.963816  0.216606
#
#       yaw_angle  yaw_rate  slip_angle_f  slip_angle_r  norm_load_f  \
# 2052   0.028582  0.115832      0.102450      0.044979      6338.75
# 2053   0.029763  0.118100      0.102373      0.045261      6338.75
# 2054   0.030966  0.120354      0.102272      0.045530      6338.75
# 2055   0.032192  0.122592      0.102147      0.045785      6338.75
# 2056   0.033440  0.124815      0.101999      0.046026      6338.75
# 2057   0.034711  0.127022      0.101828      0.046254      6338.75
# 2058   0.035999  0.128823      0.091634      0.046469      6338.75
# 2059   0.037302  0.130283      0.082718      0.046219      6338.75
#
#       norm_load_r  slip_angle_est_f  slip_angle_est_r  lat_for_f   lat_for_r
# 2052      6338.75          0.115446          0.050685    492.789     221.117
# 2053      6338.75          0.115360          0.051003    492.435     222.482
# 2054      6338.75          0.115246          0.051306    491.969     223.778
# 2055      6338.75          0.115106          0.051593    491.392     225.009
# 2056      6338.75          0.114939          0.051865    490.707     226.174
# 2057      6338.75          0.114746          0.052122    489.915     227.275
# 2058      6338.75          0.103259          0.052364    442.582     228.313
# 2059      6338.75          0.093211          0.052083    400.872     227.109

# %%
np.where(data['slip_angle_f'] == np.max(data['slip_angle_f']))
# Out:
# (array([2049, 2050]),)

# %%
yaw_clean = np.unwrap(data['yaw_angle'][::100])
plt.plot(data['t'][::100], np.rad2deg(yaw_clean) %360, '.b')

# %%
plt.plot(data['steering_angle'][:], '--r')

# %%
torque = data['torque']
torque_n = sum(torque == np.max(torque))
torque_change_time = data['t'][torque_n]
torque_change_time
# Out:
# 20.0

# %%
slip_angle = data['slip_angle_f']
plt.plot(slip_angle[interest_a:interest_b][::1], '.')

# %%
plt.plot(np.diff(slip_angle[1:1000][::10]), '.')

# %%
data_yaws = data['yaw_angle']
data_x = data['x']
data_y = data['y']
n = 1000

x = data_x[::n]
y = data_y[::n]
u = np.cos(data_yaws)[::n]
v = np.sin(data_yaws)[::n]
#u = data['long_vel'][::100]
#v = data['lat_vel'][::100]

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_aspect('equal')
plt.quiver(x,y, u,v)
plt.plot()
# Out:
# []

# %%
fig, ax = plt.subplots(figsize=(20,10))
n = 100
ax.plot(data['t'][::n], data['long_vel'][::n], '-.b', label='vx(t)')
ax.plot(data['t'][::n], data['lat_vel'][::n], '-.r', label='vy(t)')
leg = ax.legend();

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_aspect('equal')

plt.xlabel('x')
plt.ylabel('y')
plt.title('mapa 2D', fontsize=20)
#ax = plt.gca()
#ax.set_autoscale_on(False)

plt.plot(data['x'][:800], data['y'][:800])

# %%
plt.figure(figsize=(20,10))
plt.plot(data['t'], data['x'], torque_change_time, 1.5, 'r*')
plt.title('x(t)', fontsize=20)
# Out:
# Text(0.5, 1.0, 'x(t)')

# %%
plt.figure(figsize=(20,10))
plt.plot(data['t'], data['y'])
plt.title('y(t)', fontsize=20)
# Out:
# Text(0.5, 1.0, 'y(t)')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(data['t'], data['norm_load_f'], '--b', label='norm_load_f(t)')
ax.plot(data['t'], data['norm_load_r'], '--r', label='norm_load_r(t)')
leg = ax.legend();
